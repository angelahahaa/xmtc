# %% [markdown]
# # SIC code hierarchy

# %%
import numpy as np
import os,re
import pandas as pd
import pickle
import json
import collections

# %%
df = pd.read_pickle('data/sic.pkl')

# %%
df.head()
# Out:
#                                                      text categories  \
# id
# 453844  welcome to a1 lifts . professional and reliabl...    [33190]
# 914843  our friendly service , surprising range of fre...    [47110]
# 326959  wherever you want to get to in life , lloyds b...    [64191]
# 541943  stanley gibbons – the home of stamp collecting...    [47789]
# 445157  are you looking for high-quality dentistry in ...    [86230]
#
#        train/test
# id
# 453844      train
# 914843      train
# 326959      train
# 541943      train
# 445157      train

# %%
len(set([' '.join(d) for d in df.categories.values]))
# Out:
# 538

# %%
DATA_PATH = 'data/sic_hierarchy.json'
with open(DATA_PATH) as json_file:  
    hierarchy = json.load(json_file)

# %%
hierarchy['A0121x']
# Out:
# {'title': 'Growing of grapes',
#  'includes': ['growing of wine grapes and table grapes in vineyards'],
#  'excludes': ['manufacture of wine, see ##11.02']}

# %%
alpha_look = {}
for key,item in hierarchy.items():
    if key[3]!='x' or key[1]=='x':
        continue
    num = key[1:3]
    if num in alpha_look.keys():
        print('repeated key:{}'.format(key))
        break
    alpha_look[num]=key[0]

# %%
depth = [[] for _ in range(7)]
for key in hierarchy.keys():
    ind = key.find('x')
    depth[ind].append(key)
depth = [d for d in depth if d]

# %%
len(depth)
# Out:
# 5

# %%
len(depth[-1])
# Out:
# 191

# %% [markdown]
# # metrics from predictions

# %%
import os
import numpy as np
import scipy.sparse as sp

# %%
MODEL_DIR = 'outputs/190715_215817_attentionxml'
IN_DIR = 'data/dl_sic/'

ind = np.loadtxt(os.path.join(MODEL_DIR,'prediction_10_ind.txt'))
logits = np.loadtxt(os.path.join(MODEL_DIR,'prediction_10_logits.txt'))
pred = (logits>0).astype(int)
y_true =sp.load_npz(os.path.join(IN_DIR,'y_train.npz'))

# %% [markdown]
# ## p@k (multi-label)

# %%
y_true
# Out:
# <588992x538 sparse matrix of type '<class 'numpy.int64'>'
# 	with 588992 stored elements in Compressed Sparse Row format>

# %%
k = 1
data = ind*pred

# %%
logits
# Out:
# array([[-1.714, -1.798, -2.037, ..., -3.565, -3.641, -3.724],
#        [-0.279, -0.35 , -2.628, ..., -3.486, -3.758, -3.895],
#        [ 0.313, -1.697, -2.297, ..., -5.657, -5.734, -5.765],
#        ...,
#        [-0.899, -1.038, -1.948, ..., -3.909, -4.204, -4.523],
#        [ 0.263, -1.839, -2.119, ..., -4.064, -4.127, -4.508],
#        [ 1.276, -3.641, -3.956, ..., -6.19 , -6.262, -6.312]])

# %%
np.mean(np.sum(data!=0,axis=1)!=0)
# Out:
# 0.4254483962321813

# %%
y_pred = sp.coo_matrix((data, (row, col)), shape=(4, 4))

# %% [markdown]
# ## p@k (my own, p@k per label)

# %%
ll = np.split(y_true.T.indices, y_true.T.indptr)

# %%
len(ll)
# Out:
# 588994

# %%
y_true.shape
# Out:
# (588992, 538)

# %%
y_true.T.indptr
# Out:
# array([     0,      1,      2, ..., 588990, 588991, 588992], dtype=int32)

# %%
(I,J,V) = sp.find(y_true)

# %%
np.split(I,J)
# Out:
# [array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([4295], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([25030], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([29038], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([33793], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([57155], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([71961], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([78328], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([80863], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([86695], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([102775], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([121686], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([141765], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([149856], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([166336], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  array([], dtype=int32),
#  ...]

# %%
df.head()
# Out:
#                                                      text categories  \
# id
# 453844  welcome to a1 lifts . professional and reliabl...    [33190]
# 914843  our friendly service , surprising range of fre...    [47110]
# 326959  wherever you want to get to in life , lloyds b...    [64191]
# 541943  stanley gibbons – the home of stamp collecting...    [47789]
# 445157  are you looking for high-quality dentistry in ...    [86230]
#
#        train/test
# id
# 453844      train
# 914843      train
# 326959      train
# 541943      train
# 445157      train

# %%
df['sic']=df['categories'].apply(lambda x:x[0])

# %%
df['cat0']=df['sic'].apply(lambda x:[alpha_look[x[0:2]]])
df['cat1']=df['sic'].apply(lambda x:[x[0:2]])
df['cat2']=df['sic'].apply(lambda x:[x[:4]])
df['cat3']=df['categories']

# %%
df.head()
# Out:
#                                                      text categories  \
# id
# 453844  welcome to a1 lifts . professional and reliabl...    [33190]
# 914843  our friendly service , surprising range of fre...    [47110]
# 326959  wherever you want to get to in life , lloyds b...    [64191]
# 541943  stanley gibbons – the home of stamp collecting...    [47789]
# 445157  are you looking for high-quality dentistry in ...    [86230]
#
#        train/test    sic cat0  cat1    cat2     cat3
# id
# 453844      train  33190  [C]  [33]  [3319]  [33190]
# 914843      train  47110  [G]  [47]  [4711]  [47110]
# 326959      train  64191  [K]  [64]  [6419]  [64191]
# 541943      train  47789  [G]  [47]  [4778]  [47789]
# 445157      train  86230  [Q]  [86]  [8623]  [86230]

# %%
df['categories'] = df.apply(lambda x:[x['cat0'][0],x['cat1'][0],x['cat2'][0],x['cat3'][0]],axis=1)

# %%
df.head()
# Out:
#                                                      text  \
# id
# 453844  welcome to a1 lifts . professional and reliabl...
# 914843  our friendly service , surprising range of fre...
# 326959  wherever you want to get to in life , lloyds b...
# 541943  stanley gibbons – the home of stamp collecting...
# 445157  are you looking for high-quality dentistry in ...
#
#                   categories train/test    sic cat0  cat1    cat2     cat3
# id
# 453844  [C, 33, 3319, 33190]      train  33190  [C]  [33]  [3319]  [33190]
# 914843  [G, 47, 4711, 47110]      train  47110  [G]  [47]  [4711]  [47110]
# 326959  [K, 64, 6419, 64191]      train  64191  [K]  [64]  [6419]  [64191]
# 541943  [G, 47, 4778, 47789]      train  47789  [G]  [47]  [4778]  [47789]
# 445157  [Q, 86, 8623, 86230]      train  86230  [Q]  [86]  [8623]  [86230]

# %%
df.to_pickle('data/sic_hiararchy.pkl')
